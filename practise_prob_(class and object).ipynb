# %%
#Practise problem 

#Create student class that takes name and marks of 3 subjects as arguments in constructor .
#Then create a method to print avg 

#Solution ----->

class student:
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks 
    
    def get_avg(self):
        sum = 0 
        for val in self.marks:
            sum += val
        print("Hi ", self.name , "your avg score is: ",sum/3)
    
S1 = student("Atharva",[99,90,95])
S1.get_avg()
# Out:
# Hi  Atharva your avg score is:  94.66666666666667
